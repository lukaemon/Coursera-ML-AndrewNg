# %% [markdown]
# # try different $\lambda$ constant

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')

# load my own module
from helper import logistic_regression as lr  
from helper import general as general

# %%
df = pd.read_csv('ex2data2.txt', names=['test1', 'test2', 'accepted'])
x1 = np.array(df.test1)
x2 = np.array(df.test2)

y = general.get_y(df)

# %%
lambda_const = np.arange(1,101)
accuracy = [lr.accuracy(x1, x2, y, 6, l) for l in lambda_const]

fig,ax = plt.subplots(figsize=(16,10))

ax.plot(lambda_const, accuracy)
ax.set_xlabel('lambda constant')
ax.set_ylabel('accuracy')
