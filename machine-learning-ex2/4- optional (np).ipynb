# %% [markdown]
# # try different $\lambda$ constant

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('..')

# load my own module
from helper import logistic_regression as lr  
from helper import general as general

# %%
lambda_const = np.arange(1,101)
accuracy = [lr.logistic_regression(6, l)['accuracy'] for l in lambda_const]

fig,ax = plt.subplots(figsize=(16,10))

ax.plot(lambda_const, accuracy)
ax.set_xlabel('lambda constant')
ax.set_ylabel('accuracy')
