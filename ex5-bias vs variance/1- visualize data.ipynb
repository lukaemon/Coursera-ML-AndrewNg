# %%
# %reload_ext autoreload
# %autoreload 2

import sys
sys.path.append('..')

from helper import linear_regression as lr
from helper import general

import numpy as np
import pandas as pd
from altair import Chart  # try altair

# %%
X, y, Xval, yval, Xtest, ytest = lr.load_data()

# %%
df = pd.DataFrame({'water_level':X, 'flow':y})
Chart(df).mark_circle().encode(
    x='water_level',
    y='flow')
# Out:
# <div class="vega-embed" id="e56fb6cf-409f-4f77-81d6-e5795eb91339"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
