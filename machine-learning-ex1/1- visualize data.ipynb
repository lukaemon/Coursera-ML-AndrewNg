# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('ex1data1.txt', names=['population', 'profit'])

# %%
df.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# population    97 non-null float64
# profit        97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ***
# # take a look at raw data

# %%
# pandas built-in
df.plot(x='population', y='profit', kind='scatter', figsize=(10,10))

# %%
# bokeh
import bokeh.charts as bc
from bokeh.plotting import show
from bokeh.io import output_notebook # need this for inline bokeh

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1d5857ad-ec97-4a5d-8f28-762ced397ae5">Loading BokehJS ...</span>
#     </div>

# %%
fig = bc.Scatter(df, 'population', 'profit')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="db947cea-8d59-4d41-a566-3798bfa131f7"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db947cea-8d59-4d41-a566-3798bfa131f7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db947cea-8d59-4d41-a566-3798bfa131f7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"7291966d-b4c4-4ec8-82c1-2753b7f8f3d1":{"roots":{"references":[{"attributes":{"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"}},"id":"ee7ce1d7-2539-4250-9a7e-555fbe2b6c61","type":"ResetTool"},{"attributes":{},"id":"2f859f98-6fe6-4ff8-86d4-7fb3a80be451","type":"ToolEvents"},{"attributes":{"callback":null,"end":23.920610000000003,"start":3.30929},"id":"35027f03-547a-45f4-91e8-3628a02e3a33","type":"Range1d"},{"attributes":{"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"},"ticker":{"id":"52259515-a774-4afc-9451-9557eea55a22","type":"BasicTicker"}},"id":"70515546-7736-4eb6-b14b-65f9148af401","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"},"ticker":{"id":"bce3c1d9-1cfd-44cb-bd4c-feb79707c609","type":"BasicTicker"}},"id":"5c11c2be-ac83-4c2c-b285-c4dca6c8a952","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"536f0ba2-f28f-46e8-883a-43c87496ec01","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"}},"id":"8de8b6b2-999a-428e-8012-92187a2483d1","type":"SaveTool"},{"attributes":{"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"}},"id":"f706b93d-1d43-42c1-9a4f-beae0eab47b5","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"51fe0379-db39-46be-bbee-4c55249be4fa","type":"PanTool"},{"id":"f706b93d-1d43-42c1-9a4f-beae0eab47b5","type":"WheelZoomTool"},{"id":"5c835f01-2c5e-45e2-abf6-7d6d0eb230da","type":"BoxZoomTool"},{"id":"8de8b6b2-999a-428e-8012-92187a2483d1","type":"SaveTool"},{"id":"ee7ce1d7-2539-4250-9a7e-555fbe2b6c61","type":"ResetTool"},{"id":"192627dd-3af6-4662-8ef5-4cc0db2e7093","type":"HelpTool"}]},"id":"7398e420-d95b-4d71-b6e2-2447eeb76da1","type":"Toolbar"},{"attributes":{},"id":"0362d0b6-2081-4d9a-a19d-fb103f14fdc2","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"676d1567-2bb9-4bd9-83f0-b3b6b47c355f","type":"Circle"},{"attributes":{"overlay":{"id":"536f0ba2-f28f-46e8-883a-43c87496ec01","type":"BoxAnnotation"},"plot":{"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"}},"id":"5c835f01-2c5e-45e2-abf6-7d6d0eb230da","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"1931e844-ca18-47ea-9ab9-42dc641bd3b0","type":"LinearAxis"}],"left":[{"id":"a4e4a742-bfd6-48c8-826c-e9c3e51fa1c5","type":"LinearAxis"}],"renderers":[{"id":"536f0ba2-f28f-46e8-883a-43c87496ec01","type":"BoxAnnotation"},{"id":"afb976a7-c5e3-49d4-bae8-88c046f6ae31","type":"GlyphRenderer"},{"id":"87f39001-a0c6-47d5-a92d-037854dc7c05","type":"Legend"},{"id":"1931e844-ca18-47ea-9ab9-42dc641bd3b0","type":"LinearAxis"},{"id":"a4e4a742-bfd6-48c8-826c-e9c3e51fa1c5","type":"LinearAxis"},{"id":"70515546-7736-4eb6-b14b-65f9148af401","type":"Grid"},{"id":"5c11c2be-ac83-4c2c-b285-c4dca6c8a952","type":"Grid"}],"title":{"id":"1954ffa7-fac3-49bb-ad8d-0688cbc3696a","type":"Title"},"tool_events":{"id":"2f859f98-6fe6-4ff8-86d4-7fb3a80be451","type":"ToolEvents"},"toolbar":{"id":"7398e420-d95b-4d71-b6e2-2447eeb76da1","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"35027f03-547a-45f4-91e8-3628a02e3a33","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"601f140a-44b3-476f-a4c8-dbf96a298d7f","type":"Range1d"}},"id":"ac66f5c5-ec87-4186-90c1-7d0edf626d9e","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"bce3c1d9-1cfd-44cb-bd4c-feb79707c609" ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %%
# seaborn
import seaborn as sns
sns.set(context="notebook", style="darkgrid", palette="dark")

# %%
sns.jointplot('population', 'profit', df, kind='reg', size=10)
# Out:
# /Users/lucas/anaconda/envs/tf/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
