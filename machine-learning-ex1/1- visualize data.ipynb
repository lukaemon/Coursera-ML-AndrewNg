# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('ex1data1.txt', names=['population', 'profit'])

# %%
df.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# population    97 non-null float64
# profit        97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ***
# # take a look at raw data

# %%
# pandas built-in
df.plot(x='population', y='profit', kind='scatter', figsize=(10,10))

# %%
# bokeh
import bokeh.charts as bc
from bokeh.plotting import show
from bokeh.io import output_notebook # need this for inline bokeh

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="17e49710-fa75-4e1f-a829-9b806c8f2f20">Loading BokehJS ...</span>
#     </div>

# %%
fig = bc.Scatter(df, 'population', 'profit')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e9907275-ac41-4636-a293-3297ea949a1d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e9907275-ac41-4636-a293-3297ea949a1d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e9907275-ac41-4636-a293-3297ea949a1d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"06761fd2-5e0c-4417-955d-c1a6c85b24d2":{"roots":{"references":[{"attributes":{"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"}},"id":"fa99ad75-8c67-4a58-8921-d84cf459d85c","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"}},"id":"dc4df04d-bb99-4cbd-839b-d443b0a1f4a4","type":"HelpTool"},{"attributes":{},"id":"16d13283-2821-48e2-a9b5-1f90e567e64d","type":"BasicTicker"},{"attributes":{"axis_label":"profit","formatter":{"id":"f564b312-dc78-49be-a2c4-f00beccecbd1","type":"BasicTickFormatter"},"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cae4e3d-0de8-4cc0-bf8e-1624be1fcdd6","type":"BasicTicker"}},"id":"c0861aeb-4a2e-4c63-8965-241e8f148c4f","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"},"ticker":{"id":"0cae4e3d-0de8-4cc0-bf8e-1624be1fcdd6","type":"BasicTicker"}},"id":"131f6bb6-ee8e-4b14-8c17-d55e7d58c10a","type":"Grid"},{"attributes":{"below":[{"id":"21c35ba5-e7bf-48da-9890-a3e3b021073e","type":"LinearAxis"}],"left":[{"id":"c0861aeb-4a2e-4c63-8965-241e8f148c4f","type":"LinearAxis"}],"renderers":[{"id":"bcab1841-7cfc-4843-8a7a-a16273ccd718","type":"BoxAnnotation"},{"id":"d9b5ffbb-902e-48c4-aed3-9a8614465bf2","type":"GlyphRenderer"},{"id":"e4d56261-5476-46e9-a4a9-8f3b452217f4","type":"Legend"},{"id":"21c35ba5-e7bf-48da-9890-a3e3b021073e","type":"LinearAxis"},{"id":"c0861aeb-4a2e-4c63-8965-241e8f148c4f","type":"LinearAxis"},{"id":"0aed7c32-3ad4-4813-8574-eacba6230280","type":"Grid"},{"id":"131f6bb6-ee8e-4b14-8c17-d55e7d58c10a","type":"Grid"}],"title":{"id":"ecdf4c53-b7ae-4a99-a89d-dfd54c5e1dc6","type":"Title"},"tool_events":{"id":"c93fda00-928b-42e7-83c3-ee3c732a9a2b","type":"ToolEvents"},"toolbar":{"id":"18cd0a14-0d1c-4745-b5f8-67d8db4b4343","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"c367447d-d702-4567-a74b-356af97b2d48","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"f02e7716-4a0a-41d3-a472-ce6585c1f194","type":"Range1d"}},"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"}},"id":"5942c365-9081-4658-8270-4af5c39d2f62","type":"ResetTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"e2579a12-68f7-4ad4-956c-ffe7329d933c","type":"Circle"},{"attributes":{"plot":{"id":"860ab074-e26b-4d64-b56c-4c15363af870","subtype":"Chart","type":"Plot"}},"id":"26267c57-be19-4961-b4f3-09a8065bde5e","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"86b2cfa5-d5d3-42e6-b1eb-6953b001605f","type":"PanTool"},{"id":"fa99ad75-8c67-4a58-8921-d84cf459d85c","type":"WheelZoomTool"},{"id":"4febf9e6-a529-452f-ae8b-effea21b3d2a","type":"BoxZoomTool"},{"id":"26267c57-be19-4961-b4f3-09a8065bde5e","type":"SaveTool"},{"id":"5942c365-9081-4658-8270-4af5c39d2f62","type":"ResetTool"},{"id":"dc4df04d-bb99-4cbd-839b-d443b0a1f4a4","type":"HelpTool"}]},"id":"18cd0a14-0d1c-4745-b5f8-67d8db4b4343","type":"Toolbar"},{"attributes":{},"id":"f564b312-dc78-49be-a2c4-f00beccecbd1","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":23.920610000000003,"start":3.30929},"id":"c367447d-d702-4567-a74b-356af97b2d48","type":"Range1d"},{"attributes":{"callback":null,"column_names":["y_values","x_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,n ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[46]</strong>&gt;</code></p>

# %%
# seaborn
import seaborn as sns
sns.set(context="notebook", style="darkgrid", palette="dark")

# %%
sns.lmplot('population', 'profit', df, size=10)
