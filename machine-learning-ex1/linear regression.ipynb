# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('ex1data1.txt', names=['population', 'profit'])

# %%
df.head()
# Out:
#    population   profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 2 columns):
# population    97 non-null float64
# profit        97 non-null float64
# dtypes: float64(2)
# memory usage: 1.6 KB

# %% [markdown]
# ***
# # take a look at raw data

# %%
# pandas built-in
df.plot(x='population', y='profit', kind='scatter', figsize=(10,10))

# %%
# bokeh
import bokeh.charts as bc
from bokeh.plotting import show
from bokeh.io import output_notebook # need this for inline bokeh

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d788330b-af10-4ad9-bc2d-4572c60afcc5">Loading BokehJS ...</span>
#     </div>

# %%
fig = bc.Scatter(df, 'population', 'profit')
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="f2bb65f7-d4cf-4694-ab98-4140b139954a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2bb65f7-d4cf-4694-ab98-4140b139954a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2bb65f7-d4cf-4694-ab98-4140b139954a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"45c2a6a6-87fd-4ddf-8878-244db51c3ecf":{"roots":{"references":[{"attributes":{"callback":null,"end":26.82977,"start":-5.3634699999999995},"id":"2943fe4f-1516-4fc1-9bbd-eb06c81e2278","type":"Range1d"},{"attributes":{"axis_label":"population","formatter":{"id":"b132629f-187f-4337-8919-350fbe5180b1","type":"BasicTickFormatter"},"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"},"ticker":{"id":"93a91a24-7700-4951-bc07-62cea652aeae","type":"BasicTicker"}},"id":"3cd291b1-f6ff-4dfe-a584-d4e4ebbfc32f","type":"LinearAxis"},{"attributes":{"below":[{"id":"3cd291b1-f6ff-4dfe-a584-d4e4ebbfc32f","type":"LinearAxis"}],"left":[{"id":"5dbee7a5-1905-4390-a73e-1eba66d89fb4","type":"LinearAxis"}],"renderers":[{"id":"2b6728dd-960d-4693-afbf-681817c6a4eb","type":"BoxAnnotation"},{"id":"2657c07d-ec8f-4d29-a742-6293212239cf","type":"GlyphRenderer"},{"id":"8bb9ae72-4dbc-4e72-b9ae-58dd5cff503d","type":"Legend"},{"id":"3cd291b1-f6ff-4dfe-a584-d4e4ebbfc32f","type":"LinearAxis"},{"id":"5dbee7a5-1905-4390-a73e-1eba66d89fb4","type":"LinearAxis"},{"id":"8daec741-0ea3-4a28-8900-2e0adfc0a3a8","type":"Grid"},{"id":"efcf1687-7bf4-4fc4-b34c-14eef865976b","type":"Grid"}],"title":{"id":"d72a0152-110b-490e-b7a0-0cc9f3045a9d","type":"Title"},"tool_events":{"id":"b8c99332-db6e-48b8-833a-4054c584c313","type":"ToolEvents"},"toolbar":{"id":"eadee181-ac54-488e-a4c4-5310725f170c","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"ad9d46bd-f2d5-4255-8e64-c189d9550f8d","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"2943fe4f-1516-4fc1-9bbd-eb06c81e2278","type":"Range1d"}},"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"},"ticker":{"id":"6e63f100-0548-4a4c-abfc-bebb0ba20b0e","type":"BasicTicker"}},"id":"efcf1687-7bf4-4fc4-b34c-14eef865976b","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"4e3743c5-1aea-4196-8f88-9b5deab4bb1a","type":"PanTool"},{"id":"33c1bbb8-4c5d-47df-b405-b2aa34e64f31","type":"WheelZoomTool"},{"id":"1144fdb4-55f4-40f9-b006-59cc280b9311","type":"BoxZoomTool"},{"id":"436742a1-79c2-428a-9a0f-3a5478f05e49","type":"SaveTool"},{"id":"309e5bff-5550-4d1c-a250-4736f6024eac","type":"ResetTool"},{"id":"817c0e9b-2ca1-48f2-bef1-65da60c5f905","type":"HelpTool"}]},"id":"eadee181-ac54-488e-a4c4-5310725f170c","type":"Toolbar"},{"attributes":{"overlay":{"id":"2b6728dd-960d-4693-afbf-681817c6a4eb","type":"BoxAnnotation"},"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"}},"id":"1144fdb4-55f4-40f9-b006-59cc280b9311","type":"BoxZoomTool"},{"attributes":{},"id":"6e63f100-0548-4a4c-abfc-bebb0ba20b0e","type":"BasicTicker"},{"attributes":{"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"}},"id":"309e5bff-5550-4d1c-a250-4736f6024eac","type":"ResetTool"},{"attributes":{},"id":"93a91a24-7700-4951-bc07-62cea652aeae","type":"BasicTicker"},{"attributes":{"data_source":{"id":"9129ae49-8b1b-447f-96cd-6b23f6746202","type":"ColumnDataSource"},"glyph":{"id":"427d173b-bc3f-44a7-abb7-84973d37c5fd","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"2657c07d-ec8f-4d29-a742-6293212239cf","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"}},"id":"436742a1-79c2-428a-9a0f-3a5478f05e49","type":"SaveTool"},{"attributes":{"plot":{"id":"84bc7e42-3a6c-4c57-bee7-cf1d5cd7e46f","subtype":"Chart","type":"Plot"},"ticker":{"id":"93a91a24-7700-4951-bc07-62cea652aeae","type":"BasicTicker"}},"id":"8daec741-0ea3-4a28-8900-2e0adfc0a3a8","type":"Grid"},{"attributes":{"callback":null,"end":23.920610000000003,"start":3.30929},"id":"ad9d46bd-f2d5-4255-8e64-c189d9550f8d","type":"Range1d"},{"attributes":{},"id":"b8c99332-db6e-48b8-833a-4054c584c313","type":"ToolEvents ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[34]</strong>&gt;</code></p>

# %%
# seaborn
import seaborn as sns
sns.set(context="notebook", style="darkgrid", palette="dark")

# %%
sns.jointplot('population', 'profit', df, kind='reg', size=10)
# Out:
# /home/lucas/anaconda3/envs/tf/lib/python3.5/site-packages/statsmodels/nonparametric/kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
